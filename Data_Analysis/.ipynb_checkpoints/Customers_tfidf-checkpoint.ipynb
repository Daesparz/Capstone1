# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer 
from nltk.tokenize import word_tokenize, sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import json
import nltk
import re

# %%
df = pd.read_csv('../Data_Extraction/reviews_yelp_scrapping.csv')

# %%
"""
from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
all credits go to alko and arturomp @ stack overflow.
"""

f = open('../Data_Extraction/contractionList.txt', 'r')
cList = json.loads(f.read())
c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text)

# %%
wpt = nltk.WordPunctTokenizer()
#stop_words = nltk.corpus.stopwords.words('english')
#new_words=('yeah', 'yea')
#for i in new_words:
    #stop_words.append(i)

stop_words = ['do','got','did','made', 'make','also','been','like','is', 'was', 'were', 'are', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'in', 'out', 'on', 'off', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'why', 'how', 'all', 'any', 'both', 'each', 'other', 'some', 'such', 'same', 'so', 'than', 'too', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'yeah', 'yea']

# %%
stemmer = PorterStemmer() 
    
def normalizer(paragrahp):
    paragrahp = expandContractions(paragrahp.lower())
    paragrahp_c = paragrahp.split('.')[:-1]
    # lower case and remove special character/whitespace
    paragrahp = [re.sub(r'[^a-zA-Z\s]','', sentence) for sentence in paragrahp_c]
    paragrahp = [sentence.strip() for sentence in paragrahp]
    tokens = [wpt.tokenize(sentence) for sentence in paragrahp]
    tokens_filtered = [[word for word in token if word not in stop_words] for token in tokens]
    #tokens_stemmed = [[stemmer.stem(word) for word in token] for token in tokens_filtered]
    paragrahp_norm = [' '.join(tokens) for tokens in tokens_filtered]
    return paragrahp_norm

# %%
def key_word_extractor(norm_corpus):
    tv = TfidfVectorizer(min_df=0., max_df=1., use_idf=True, ngram_range=(2,2), max_features=20)
    tv_matrix = tv.fit_transform(norm_corpus)
    tv_matrix = tv_matrix.toarray()

    idx = [i for i in range(len(norm_corpus))]
    vocab = tv.get_feature_names()
    df_tfidV = pd.DataFrame(np.round(tv_matrix, 2), columns=vocab, index=idx)

    key_values = []
    key_words = []
    for i in range(len(norm_corpus)):
        for column in vocab:
            if df_tfidV[column][i] > 0.20:
                key_values.append(df_tfidV[column][i])
                key_words.append(column)
    return key_words, key_values

# %%
#df.drop_duplicates(subset='Description',keep='first', inplace=False)

# %%
reviews = df['Description']
corpora = ''
for review in reviews:
    corpora = corpora.join('review')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-8bad2dc4f5b4> in <module>
#       2 corpora = ''
#       3 for review in reviews:
# ----> 4     corpora = corpora.join('review')
#
# KeyboardInterrupt:

# %%
key_words = [key_word_extractor(normalizer(review))[0] for review in df['Description']]   
key_values = [key_word_extractor(normalizer(review))[1] for review in df['Description']]

# %%
l_words = []
l_values = []
for list_words in key_words:
    l_words = [*l_words, *list_words] 
    
for list_values in key_values:
    l_values = [*l_values, *list_values]

# %%
data = {'key_words': l_words, 'key_values': l_values}
df_keys = pd.DataFrame(data)

# %%
df_keys[df_keys['key_values']>0.6].head()
# Out:
#                    key_words  key_values
# 0             breakfast menu        1.00
# 1                  come back        1.00
# 2                 said hello        1.00
# 3                 said hello        1.00
# 4                coffee shop        0.64
# 5               great coffee        0.77
# 6                  come back        1.00
# 7                   not want        1.00
# 8                coffee shop        0.61
# 9               wanted place        0.79
# 10               coffee shop        0.61
# 11              wanted place        0.79
# 12               coffee shop        0.84
# 14                 seemed be        1.00
# 15           missing friends        0.73
# 16                 seemed be        0.68
# 17                cup coffee        0.71
# 18                love place        0.71
# 19              heart castro        1.00
# 20                cup coffee        0.73
# 21                 next time        0.69
# 22        morning electronic        1.00
# 23          first impression        1.00
# 27            door starbucks        0.73
# 28                 next door        0.69
# 29                 next time        1.00
# 30               coffee shop        0.61
# 31               shop castro        0.79
# 32              great coffee        1.00
# 33              have rveille        1.00
# ...                      ...         ...
# 4880                  de sel        0.71
# 4881              caramel de        0.71
# 4882                  de sel        0.71
# 4883             maple bacon        1.00
# 4884              best donut        1.00
# 4885             even though        1.00
# 4886              caramel de        0.71
# 4887                  de sel        0.71
# 4888         chocolate donut        0.73
# 4889          milk chocolate        0.69
# 4890         chocolate donut        0.73
# 4891           passion fruit        0.69
# 4892        customer service        1.00
# 4893  chocolate passionfruit        0.77
# 4894             maple bacon        0.64
# 4896             maple bacon        0.86
# 4897      chocolate hazelnut        0.71
# 4898       hazelnut lavender        0.71
# 4899                 not bad        1.00
# 4900              have donut        1.00
# 4901      chocolate hazelnut        0.71
# 4902       hazelnut lavender        0.71
# 4903           coffee donuts        1.00
# 4904        customer service        1.00
# 4905           coffee donuts        1.00
# 4906              have donut        1.00
# 4907              best donut        0.77
# 4908             maple bacon        0.64
# 4909          milk chocolate        1.00
# 4910             maple bacon        1.00
#
# [3978 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
# the histogram of the data
plt.grid(axis='y', alpha=0.75)
plt.hist(np.asarray(df_keys['key_values']), bins = 20, density=True, color='#0504aa', alpha=0.7, rwidth=0.85)
plt.xlabel('bins of words')
plt.ylabel('Tfidf')
plt.title('Tfidf of an expert review')
plt.show()

# %%
df_keys.to_csv('key_words.csv', index=False)

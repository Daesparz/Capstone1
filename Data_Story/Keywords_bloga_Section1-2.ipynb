# %% [markdown]
# # Data Storytelling

# %% [markdown]
# ## Part 1: What are expert reviewers talking about?
# What kind of information we can extract from coffee blogs? The following analysis was applied to one of the four blogs included in the project. We extracted TF-IDF feature vectors for the text to find meaningful pairs of terms for classifying them in categories and sections relatives to the complete experience in the coffee shop. Now, we want to discover which ones play a fundamental role in reviews.
#
# (This is the continuation of Pre-processing notebook called *Tfidf_blog_Section1-1.ipynb*)

# %% [markdown]
# Importing all relevant packages

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# Reading data from **preprocessing** folder. We included categories and sections in *key_words.csv* to build *key_words_categorized.csv*, the file that it will be used in this stage. Both files can be founded in the folder.

# %%
df = pd.read_csv('../Data_Story/preprocessing/key_words_categorized.csv')

# %% [markdown]
# There are a couple of **None cells**, according to the classify criteria. Firstly, we clean DataFrame, extracting None from *category* and *section* columns

# %%
df_filt= df[(df['category']!='None')&(df['section']!='None')]

# %%
df_filt.head()
# Out:
#          key_words  key_values category    section
# 1      toast crave        0.71     food      baked
# 7   toast cravings        0.41     food      baked
# 8      best coffee        0.58   coffee  sentiment
# 11    best parklet        0.26    place  sentiment
# 14       find seat        0.26    place       stay

# %% [markdown]
# Grouping data under *category* and *section* columns:

# %%
df_count = df_filt.groupby(['category','section']).count()

# %% [markdown]
# Results are the following:

# %% [markdown]
# ### Category 1: Coffee
# As we mentioned in the previous notebook, sections for coffee are about the experience that involves the cup of coffee: types of drinks (including all varieties of coffee drinks, wine and tea), roasting information (own roasters, origin of roast, types of roast offered to customers), beans, baristas (expertise of baristas) and sentiment (how do you feel in front of this drink).

# %%
df1 = df_count.reset_index()
df_coffee = df1[df1['category'] == 'coffee'].sort_values('key_values')
df_coffee
# Out:
#   category    section  key_words  key_values
# 0   coffee    barista          5           5
# 1   coffee      beans         11          11
# 3   coffee      roast         21          21
# 4   coffee  sentiment         22          22
# 2   coffee     drinks        124         124

# %%
sns.set_style("whitegrid")

g = sns.catplot(x="section", y = 'key_values', data=df_coffee, saturation=.5,
                kind="bar", ci=None, aspect=1.2, palette='Blues')
g.set_axis_labels("Coffee sections", "Phrases") \
.set_titles("{col_name} {col_var}")\
.set_xticklabels(["Baristas", "Beans", "Roast", "Sentiment", "Drinks"]) 

sns.despine(offset=10, trim=True)

# %% [markdown]
# Total of key coffee phrases are:

# %%
total = df_coffee.groupby('category').sum()['key_values']

# %% [markdown]
# And each section represents:

# %%
df_coffee['key_values'].apply(lambda n: n*100//total)
# Out:
# category  coffee
# 0              2
# 1              6
# 3             11
# 4             12
# 2             67

# %% [markdown]
# What kind of phrases do we find here?

# %%
df_phrases = df_filt[(df_filt['category']=='coffee') & (df_filt['section']=='drinks')]
df_phrases.head(20)
# Out:
#                 key_words  key_values category section
# 47            cafe offers        0.29   coffee  drinks
# 48            known snowy        0.29   coffee  drinks
# 50               over ice        0.29   coffee  drinks
# 52    pellegrino espresso        0.29   coffee  drinks
# 53            plover cold        0.29   coffee  drinks
# 54           snowy plover        0.29   coffee  drinks
# 60         authentic soda        0.24   coffee  drinks
# 113      drinks featuring        0.28   coffee  drinks
# 114       espresso drinks        0.28   coffee  drinks
# 121           offers pour        0.28   coffee  drinks
# 123        overs espresso        0.28   coffee  drinks
# 124            pour overs        0.28   coffee  drinks
# 125       snowbird offers        0.28   coffee  drinks
# 135          bottled cold        0.32   coffee  drinks
# 136         brew coldbrew        0.32   coffee  drinks
# 137             cold brew        0.32   coffee  drinks
# ...

# %%
text = ' '.join(df_phrases['key_words'])
wordcloud = WordCloud(background_color="white", max_font_size=50, colormap='copper').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Then, 67% of coffee phrases are relatives to **types of drinks**, follows for **feelings** and **roast features**. Baristas and Beans have lower predominance.

# %% [markdown]
# ### Category 2: Food
# In this case, we extract terms as pastries, toasts, sweet baked items, light sandwiches, salads, breakfast, brunch, and lunch. Repeating the previous exercise:

# %%
df_food = df1[df1['category'] == 'food'].sort_values('key_values')
df_food
# Out:
#   category    section  key_words  key_values
# 7     food     brunch          4           4
# 9     food  sentiment          5           5
# 6     food  breakfast         13          13
# 8     food      lunch         15          15
# 5     food      baked         46          46

# %%
#sns.set_style("whitegrid")
g = sns.catplot(x="section", y = 'key_values', data=df_food, saturation=.5,
                kind="bar", ci=None, aspect=1.2, palette='GnBu')

g.set_axis_labels("Food sections", "Phrases") \
.set_titles("{col_name} {col_var}") \
.set_xticklabels(["Brunch", "Sentiment", "Breakfast", "Lunch", "Baked"])

sns.despine(offset=10, trim=True)

# %% [markdown]
# Total of key food phrases are:

# %%
total = df_food.groupby('category').sum()['key_values']
total
# Out:
# category
# food    83
# Name: key_values, dtype: int64

# %% [markdown]
# And each one section represents:

# %%
df_food['key_values'].apply(lambda n: n*100//total)
# Out:
# category  food
# 7            4
# 9            6
# 6           15
# 8           18
# 5           55

# %% [markdown]
# In the food phrases universe, **baked** items have the highest predominance (55%) and it makes sense, because the current trends of coffee shops put more prominence in drinks and then in food items, usually snacks and small elements. **Lunch** and **Breakfast** are the next priority with a predominance of 18% and 15%, respectively.

# %% [markdown]
# What kind of phrases do we find here?

# %%
df_phrases = df_filt[(df_filt['category']=='food') & (df_filt['section']=='baked')]
df_phrases.head(20)
# Out:
#               key_words  key_values category section
# 1           toast crave        0.71     food   baked
# 7        toast cravings        0.41     food   baked
# 51        pastries free        0.29     food   baked
# 62          breads have        0.24     food   baked
# 200       donut special        0.41     food   baked
# 226      artisan breads        0.23     food   baked
# 228       batter bakery        0.23     food   baked
# 229       breads batter        0.23     food   baked
# 240  pastries firebrand        0.23     food   baked
# 241       plus pastries        0.23     food   baked
# 245    bakers excellent        0.28     food   baked
# 248    bread divisadero        0.28     food   baked
# 251     excellent bread        0.28     food   baked
# 269          bread road        0.26     food   baked
# 271           grab loaf        0.26     food   baked
# 273           jam array        0.26     food   baked
# 274          loaf bread        0.26     food   baked
# ...

# %%
text = ' '.join(df_phrases['key_words'])
wordcloud = WordCloud(background_color="white", max_font_size=50, colormap='copper').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Category 3: Place
# We considered as place everything related to the physical space inside and outside of the coffee shop. Decoration in walls, musical elements and books are some examples of inside features. We discover some allusions to the features on the streets, sunsets, scenery beyond the coffee shop itself but possible thanks to the location of coffee. Additionally, there is information about coffee dynamic (for here, to go), availability of wifi and size of the shop.

# %%
df_place = df1[df1['category'] == 'place'].sort_values('key_values')

# %%
g = sns.catplot(x="section", y = 'key_values', data=df_place, saturation=.5,
                kind="bar", ci=None, aspect=1.5, palette='coolwarm')

g.set_axis_labels("Place sections", "Phrases") \
.set_titles("{col_name} {col_var}") \
.set_xticklabels(["Wifi", "Size", "Sentiment", "To go", "For here", "Outside", "Decoration"]) 

sns.despine(offset=10, trim=True)

# %% [markdown]
# Total of key place phrases are:

# %%
total = df_place.groupby('category').sum()['key_values']
total
# Out:
# category
# place    116
# Name: key_values, dtype: int64

# %% [markdown]
# And each one section represents:

# %%
df_place['key_values'].apply(lambda n: n*100//total)
# Out:
# category  place
# 16            6
# 14            6
# 13            8
# 11            9
# 15           17
# 12           20
# 10           31

# %% [markdown]
# **Decoration** has majority predominance with 31%, follows by features **out** of the coffee shop (20%). There is special attention for parklets and what part of the city you could see from your seat in the coffee shop, for example. Additionally, sections **For here** and **To go** as one big section would be in the second predominance (26%). This last information is extremely important to choose a shop, because define an essential part of the type of experience that you will have.

# %% [markdown]
# What kind of phrases do we find here?

# %%
df_phrases = df_filt[(df_filt['category']=='place') & (df_filt['section']=='deco')]
df_phrases.head(20)
# Out:
#                     key_words  key_values category section
# 76                 area piano        0.22    place    deco
# 77              books patrons        0.22    place    deco
# 88                 piano free        0.22    place    deco
# 92              shelves books        0.22    place    deco
# 217               most scenic        0.22    place    deco
# 221              scenic might        0.22    place    deco
# 259            communal table        0.32    place    deco
# 267              table inside        0.32    place    deco
# 268              array hearty        0.26    place    deco
# 308  technologically advanced        0.27    place    deco
# 319          beautiful mobile        0.29    place    deco
# 323          into picturesque        0.29    place    deco
# 324             mobile coffee        0.29    place    deco
# 328          picturesque cafe        0.29    place    deco
# 358           interior leaves        0.38    place    deco
# ...

# %%
text = ' '.join(df_phrases['key_words'])
wordcloud = WordCloud(background_color="white", max_font_size=50, colormap='copper').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# To sum up, we discovered what types of drinks, roast features, baked food, decoration, outsides and dynamic of the coffee shop are most predominance classes of information in the blog analyzed. Drinks from coffee category have three times more appearance (124) that the most meaningful sections in food and place categories. Baked and Decoration have similar number of appearances (46 and 36 respectively).

# %%
API_KEY = '7hlj8jHWV-jS57G2WGJEO0ROpEZAedHNxxd_4JMu1rdOW8ltXVO6Weeo-f_Tmpsm2_p-eG-Bq0wXMHHkerq33ul52MwZGynRQHwphIPSbeZl9BwZ_R-xuGg-Uqm-XHYx'

# %%
client_id = 'ZPsDRbHzglthukFTIg4SEA'

# %%
import requests
import json

headers = {'Authorization': 'Bearer %s' % API_KEY}
url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'coffee','location':'San Francisco', 'limit':'50'}

# %%
req=requests.get(url, params=params, headers=headers)
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
parsed = json.loads(req.text)
#parsed

# %%
businesses = parsed['businesses']
#print (businesses)

# %%
ids = [business['id'] for business in businesses]   
names = [business['name'] for business in businesses]

len(ids)
# Out:
# 50

# %%
import pandas as pd
description = []

for id in ids:
    url = "https://api.yelp.com/v3/businesses/" + id + "/reviews"
    req = requests.get(url, headers=headers)
    parsed = json.loads(req.text)
    reviews = parsed['reviews']
    description.append([review['text'] for review in reviews])
    
corpus_df = pd.DataFrame({'Name': names, 
                          'Description': description})
#corpus_df = corpus_df[['Name', 'Description']]

# %%
corpus_df
# Out:
#                              Name  \
# 0              Four Barrel Coffee
# 1             Réveille Coffee Co.
# 2                        The Mill
# 3     Rise & Grind Coffee and Tea
# 4                            Home
# 5             Native Twins Coffee
# 6                            Home
# 7        Blue Danube Coffee House
# 8                 Snowbird Coffee
# 9        Andytown Coffee Roasters
# 10  Wrecking Ball Coffee Roasters
# 11              Neighbor's Corner
# 12              Sightglass Coffee
# 13       Flywheel Coffee Roasters
# 14                         Hollow
# 15            The Coffee Movement
# 16    Golden Bear Trading Company
# 17         Ritual Coffee Roasters
# 18   Fifty / Fifty Coffee and Tea
# 19              Sightglass Coffee
# 20             Saint Frank Coffee
# 21         Ritual Coffee Roasters
# 22          Weaver's Coffee & Tea
# 23              Stanza Coffee Bar
# 24                   Philz Coffee
# 25             Wooden Coffeehouse
# 26                 Ballast Coffee
# 27             Blue Bottle Coffee
# 28                     CoffeeShop
# 29               Jane on Fillmore
# 30                 Pinhole Coffee
# 31          Castro Coffee Company
# 32       Folklores Coffee Traders
# 33                       Bernie's
# 34         Spike's Coffees & Teas
# 35          Contraband Coffee Bar
# 36                  Saltroot Café
# 37                         Chalos
# 38               UpForDayz Coffee
# 39                       Farley's
# 40       Andytown Coffee Roasters
# 41                   YakiniQ Cafe
# 42          Verve Coffee Roasters
# 43         Ritual Coffee Roasters
# 44              Sightglass Coffee
# 45             Blue Bottle Coffee
# 46                   B Patisserie
